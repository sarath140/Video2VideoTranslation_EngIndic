# %%
import os
from pydub import AudioSegment

from google.colab import drive, userdata
drive.mount('/content/drive', force_remount=True)

# ========================
# HELPER FUNCTION TO REDUCE FILE SIZE
# ========================

def reduce_wav_size(file_path, target_size_mb=25, output_path=None):
    """
    Reduces the size of a .wav file by adjusting bitrate, sample rate, and channels.
    Ensures the resulting file is under the target size (in MB).
    """
    # Load the audio file
    audio = AudioSegment.from_wav(file_path)

    # Convert to mono (if stereo)
    audio = audio.set_channels(1)

    # Reduce sample rate (e.g., 22050 Hz instead of 44100 Hz)
    audio = audio.set_frame_rate(22050)

    # Export the reduced audio to a temporary location to check the size
    temp_path = output_path if output_path else file_path
    audio.export(temp_path, format="wav", codec="pcm_s16le")

    # Check the file size, and adjust further if necessary
    while os.path.getsize(temp_path) > target_size_mb * 1024 * 1024:
        print(f"File too large ({os.path.getsize(temp_path)} bytes). Reducing further...")

        # Reduce further sample rate, or trim silence
        audio = audio.set_frame_rate(audio.frame_rate - 1000)  # Reduce 1 kHz at a time

        # Re-export the file
        audio.export(temp_path, format="wav", codec="pcm_s16le")

    print(f"Final file size: {os.path.getsize(temp_path) / (1024 * 1024):.2f} MB")
    return temp_path

# ========================
# REDUCE FILE SIZE FOR ALL .WAV FILES IN THE INPUT FOLDER
# ========================

input_dir = "/content/drive/MyDrive/Test_28_Adnew_wav/Hindi/a"  # Input folder path
output_dir = "/content/drive/MyDrive/Test_28_Adnew_wav/Hindi/a/Reduced"  # Folder to save reduced files
os.makedirs(output_dir, exist_ok=True)

for filename in os.listdir(input_dir):
    if filename.lower().endswith(".wav"):
        file_path = os.path.join(input_dir, filename)
        output_path = os.path.join(output_dir, filename)

        print(f"🎧 Reducing size for {filename}...")

        # Reduce the file size
        reduced_file = reduce_wav_size(file_path, target_size_mb=25, output_path=output_path)

        print(f"✅ Reduced file saved at: {reduced_file}")
# Out:
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:300: SyntaxWarning: invalid escape sequence '\('
#   m = re.match('([su]([0-9]{1,2})p?) \(([0-9]{1,2}) bit\)$', token)
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:301: SyntaxWarning: invalid escape sequence '\('
#   m2 = re.match('([su]([0-9]{1,2})p?)( \(default\))?$', token)
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:310: SyntaxWarning: invalid escape sequence '\('
#   elif re.match('(flt)p?( \(default\))?$', token):
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:314: SyntaxWarning: invalid escape sequence '\('
#   elif re.match('(dbl)p?( \(default\))?$', token):
# Mounted at /content/drive
# 🎧 Reducing size for Chapter 8B - Sewing of Regular Blouse.wav...
# File too large (116417612 bytes). Reducing further...
# File too large (111137904 bytes). Reducing further...
# File too large (105858196 bytes). Reducing further...
# File too large (100578488 bytes). Reducing further...
# File too large (95298780 bytes). Reducing further...
# File too large (90019072 bytes). Reducing further...
# File too large (84739364 bytes). Reducing further...
# File too large (79459656 bytes). Reducing further...
# File too large (74179948 bytes). Reducing further...
# File too large (68900242 bytes). Reducing further...
# File too large (63620536 bytes). Reducing further...
# File too large (58340830 bytes). Reducing further...
# File too large (53061124 bytes). Reducing further...
# File too large (47781418 bytes). Reducing further...
# File too large (42501712 bytes). Reducing further...
# File too large (37222006 bytes). Reducing further...
# File too large (31942300 bytes). Reducing further...
# File too large (26662594 bytes). Reducing further...
# Final file size: 20.39 MB
# ✅ Reduced file saved at: /content/drive/MyDrive/Test_28_Adnew_wav/Hindi/a/Reduced/Chapter 8B - Sewing of Regular Blouse.wav

# %%
# ========================
# INSTALL & IMPORTS
# ========================
# !pip install -q google-generativeai pydub tqdm librosa

import os
import io
from google.colab import drive, userdata
import google.generativeai as genai
from pydub import AudioSegment
from tqdm import tqdm

# ========================
# SETUP
# ========================

# Mount Google Drive
drive.mount('/content/drive', force_remount=True)

# Securely load your Gemini API key from Colab secrets
api_key = userdata.get("GOOGLE_API_KEY")
if not api_key:
    raise ValueError("❌ No GOOGLE_API_KEY found in Colab secrets! Add it under 'More → Secrets'.")

genai.configure(api_key=api_key)

# Choose your model
model = genai.GenerativeModel("models/gemini-2.5-pro")

# Input/output folders in Google Drive
base_dir = "/content/drive/MyDrive/Test_28_Adnew_wav/"
input_dir = "/content/drive/MyDrive/Test_28_Adnew_wav/Hindi/aa"
output_dir = os.path.join(base_dir, "Test_quality")
os.makedirs(output_dir, exist_ok=True)

# ========================
# HELPER FUNCTIONS
# ========================

def transcribe_audio_file(file_path):
    """Transcribe full audio file without splitting."""
    audio = AudioSegment.from_wav(file_path)
    buffer = io.BytesIO()
    audio.export(buffer, format="wav")
    audio_bytes = buffer.getvalue()

    try:
        response = model.generate_content(
        contents=[
            {
                "role": "user",
                "parts": [
                    {"mime_type": "audio/wav", "data": audio_bytes},
                    """
                    You are a Subtitle Generator.

                    Transcribe this audio exactly as spoken in Hindi (strictly: no extra comments, strictly: no filler words)
                    in valid .srt format.

                    Before outputting, you MUST internally ensure:

                    - Each subtitle segment must contain exactly 3 sentences in same line, unless the audio ends and fewer remain.
                    - Maintain natural sentence boundaries.
                    - Combine sentences smoothly while keeping meaning and flow.
                    - Only create a new segment after exactly 3 sentences have been completed (except the final segment).
                    - Timestamp continuity must be correct and must not overlap.
                    - Format must strictly be:

                      <index>
                      HH:MM:SS,SSS --> HH:MM:SS,SSS
                      text
                      This format should be strictly followed

                    Rules:
                    1. Timestamps must be chronological and continuous.
                    2. Every segment contains exactly 3 sentences (except final).
                    3. Never generate timestamps beyond the audio duration.
                    4. If Gemini outputs incorrect timestamps, fix them BEFORE final output.
                    5. No explanations. Only the final SRT.
                    6. Include speaker labels if detectable.
                    7. Silence > 2 seconds → include:
                      [Silence]
                      with correct timestamps.


                    """
                ]
            }
        ]
    )


        return response.text.strip()
    except Exception as e:
        print("❌ Error:", e)
        return ""

# ========================
# MAIN PROCESS
# ========================

for filename in os.listdir(input_dir):
    if filename.lower().endswith(".wav"):
        file_path = os.path.join(input_dir, filename)
        print(f"\n🎧 Transcribing full audio: {filename}")

        # Get full transcription
        text = transcribe_audio_file(file_path)

        # Save TXT file
        txt_output = os.path.join(output_dir, filename.replace(".wav", ".txt"))
        with open(txt_output, "w", encoding="utf-8") as f:
            f.write(text)

        print(f"✅ Done: {filename}")
        print(f"📄 TXT saved to: {txt_output}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-4087759817.py in <cell line: 0>()
#      16
#      17 # Mount Google Drive
# ---> 18 drive.mount('/content/drive', force_remount=True)
#      19
#      20 # Securely load your Gemini API key from Colab secrets
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     193       raise ValueError('Mountpoint must not be a symlink')
#     194     if _os.path.isdir(mountpoint) and _os.listdir(mountpoint):
# --> 195       raise ValueError('Mountpoint must not already contain files')
#     196     if not _os.path.isdir(mountpoint) and _os.path.exists(mountpoint):
#     197       raise ValueError('Mountpoint must either be a directory or not exist')
#
# ValueError: Mountpoint must not already contain files

# %%
import os
import re

def normalize_timestamp(ts: str) -> str:
    """
    Normalize timestamp to 'HH:MM:SS,mmm' format.
    Handles missing hours and malformed parts.
    """
    ts = ts.strip().replace('.', ',')
    # Split at comma for milliseconds
    if ',' in ts:
        time_part, ms = ts.split(',', 1)
        ms = re.sub(r'\D', '', ms)[:3].ljust(3, '0')
    else:
        time_part, ms = ts, '000'
    parts = time_part.split(':')
    # Fill missing parts
    if len(parts) == 1:
        h, m, s = 0, 0, parts[0]
    elif len(parts) == 2:
        h, m, s = 0, parts[0], parts[1]
    else:
        h, m, s = parts[-3], parts[-2], parts[-1]
    try:
        return f"{int(h):02d}:{int(m):02d}:{int(s):02d},{ms}"
    except:
        return "00:00:00,000"


def fix_srt_file(input_path, output_path):
    """
    Reads one .srt/.txt file, fixes timestamp formatting,
    and saves a new valid .srt file.
    """
    with open(input_path, 'r', encoding='utf-8', errors='ignore') as f:
        lines = f.readlines()

    new_lines = []
    ts_pattern = re.compile(
        r'(\d{1,2}:?\d{1,2}:?\d{1,2}[.,]?\d*)\s*[-–>]+\s*(\d{1,2}:?\d{1,2}:?\d{1,2}[.,]?\d*)'
    )

    for line in lines:
        match = ts_pattern.search(line)
        if match:
            start, end = match.groups()
            start = normalize_timestamp(start)
            end = normalize_timestamp(end)
            new_lines.append(f"{start} --> {end}\n")
        else:
            new_lines.append(line)

    with open(output_path, 'w', encoding='utf-8') as f:
        f.writelines(new_lines)


def process_folder(input_folder, output_folder):
    """
    Process all .srt/.txt files in a folder recursively,
    writing fixed versions to output_folder.
    """
    os.makedirs(output_folder, exist_ok=True)

    for root, _, files in os.walk(input_folder):
        for file in files:
            if file.lower().endswith(('.srt', '.txt')):
                input_path = os.path.join(root, file)
                rel_path = os.path.relpath(input_path, input_folder)
                output_path = os.path.join(output_folder, os.path.splitext(rel_path)[0] + '.srt')

                os.makedirs(os.path.dirname(output_path), exist_ok=True)
                print(f"Fixing: {rel_path}")
                fix_srt_file(input_path, output_path)

    print("\n All files processed and saved in:", output_folder)



if __name__ == "__main__":
    input_folder = "/content/drive/My Drive/Test_quality/gemini25pro/Asr_eng/"
    output_folder = "/content/drive/My Drive/Test_quality/gemini25pro/Asr_eng_f/"

    process_folder(input_folder, output_folder)
# Out:
# Fixing: Chapter 5A - Use of Growing and Rooting Media in Floriculture_gemini_25_pro_eng_eng.txt
# Fixing: Chapter 1A - Concept of Basic Electricity Voltage, Currents, Resistance, Impedance & Power Factor.txt
#
#  All files processed and saved in: /content/drive/My Drive/Test_quality/gemini25pro/Asr_eng_f/

# %% [markdown]
# Test_quality/gemini25pro/Asr_eng/

# %%
from google.colab import drive, userdata
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# MT

# %%
from google import genai
from google.colab import drive, userdata
import os
import re
import time

# === Mount Google Drive and API ===
drive.mount('/content/drive')
os.environ["GOOGLE_API_KEY"] = userdata.get('GOOGLE_API_KEY')
client = genai.Client(api_key=os.environ["GOOGLE_API_KEY"])

# === Paths ===
base_dir = "/content/drive/My Drive/Test_quality/gemini25pro/"
asr_dir = os.path.join(base_dir, "Asr_eng")  # input SRTs
mt_dir = os.path.join(base_dir, "mt","Tel")   # translated output
os.makedirs(mt_dir, exist_ok=True)

target_language = "Telugu"
print("🟢 Ready — Processing all .srt files...")

# === SRT parsing pattern ===
pattern = r"(\d+)\s+([\d:,]+ --> [\d:,]+)\s+(.+?)(?=\n\d+\n|$)"

def translate_batch(lines):
    """Translate list of subtitle text chunks at once with Gemini."""
    joined_text = "\n".join(lines)
    prompt = f"""
You are a professional subtitle translator for Indic languages.

Translate the following subtitle dialogue into {target_language}.
Preserve meaning. Keep subtitles short and natural.
Do NOT translate numbers or timestamps.
Return one line per subtitle, in order.

Text:
{joined_text}
"""
    for _ in range(3):  # retry logic
        try:
            response = client.models.generate_content(
                model="gemini-2.5-pro",  # or gemini-2.0-pro if you have access
                contents=prompt
            )
            # Gemini's response object
            result_text = response.text.strip()
            return result_text.split("\n")
        except Exception as e:
            print("Retrying batch due to error:", e)
            time.sleep(3)
    return [""] * len(lines)


# === Loop over all SRT files ===
for f_name in os.listdir(asr_dir):
    if not f_name.lower().endswith(".srt"):
        continue

    input_file = os.path.join(asr_dir, f_name)
    print(f"\n🎬 Processing: {f_name}")

    with open(input_file, 'r', encoding='utf-8') as f:
        content = f.read()

    entries = re.findall(pattern, content, flags=re.DOTALL)
    print(f"   → {len(entries)} subtitles detected")

    translated_entries = []
    translated_text_only = []

    batch_size = 15
    for i in range(0, len(entries), batch_size):
        batch = entries[i:i+batch_size]
        orig_texts = [t[2].strip() for t in batch]

        translated_batch = translate_batch(orig_texts)

        for (num, ts, _), trans in zip(batch, translated_batch):
            translated_entries.append(f"{num}\n{ts}\n{trans}\n")
            translated_text_only.append(trans)

        print(f"   ✅ Translated segments {i+1}–{min(i+batch_size,len(entries))}")

    # Save outputs
    base = os.path.splitext(f_name)[0]
    srt_out = os.path.join(mt_dir, f"{base}_{target_language}.srt")
    txt_out = os.path.join(mt_dir, f"{base}_{target_language}.txt")

    with open(srt_out, "w", encoding='utf-8') as f:
        f.write("\n".join(translated_entries))

    with open(txt_out, "w", encoding='utf-8') as f:
        f.write("\n".join(translated_text_only))

    print(f"   📁 Saved → {srt_out}")
    print(f"   📄 Saved → {txt_out}")

print("\n✅ All files translated successfully!")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 🟢 Ready — Processing all .srt files...
#
# 🎬 Processing: Chapter 5A - Use of Growing and Rooting Media in Floriculture_gemini_25_pro_eng_eng.srt
#    → 66 subtitles detected
#    ✅ Translated segments 1–15
#    ✅ Translated segments 16–30
#    ✅ Translated segments 31–45
#    ✅ Translated segments 46–60
#    ✅ Translated segments 61–66
#    📁 Saved → /content/drive/My Drive/Test_quality/gemini25pro/mt/Tel/Chapter 5A - Use of Growing and Rooting Media in Floriculture_gemini_25_pro_eng_eng_Telugu.srt
#    📄 Saved → /content/drive/My Drive/Test_quality/gemini25pro/mt/Tel/Chapter 5A - Use of Growing and Rooting Media in Floriculture_gemini_25_pro_eng_eng_Telugu.txt
#
# 🎬 Processing: Chapter 1A - Concept of Basic Electricity Voltage, Currents, Resistance, Impedance & Power Factor.srt
#    → 129 subtitles detected
#    ✅ Translated segments 1–15
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-88703132.py in <cell line: 0>()
#      73         orig_texts = [t[2].strip() for t in batch]
#      74
# ---> 75         translated_batch = translate_batch(orig_texts)
#      76
#      77         for (num, ts, _), trans in zip(batch, translated_batch):
#
# /tmp/ipython-input-88703132.py in translate_batch(lines)
#      38     for _ in range(3):  # retry logic
#      39         try:
# ---> 40             response = client.models.generate_content(
#      41                 model="gemini-2.5-pro",  # or gemini-2.0-pro if you have access
#      42                 contents=prompt
#
# /usr/local/lib/python3.12/dist-packages/google/genai/models.py in generate_content(self, model, contents, config)
#    5216     while remaining_remote_calls_afc > 0:
#    5217       i += 1
# -> 5218       response = self._generate_content(
#    5219           model=model, contents=contents, config=parsed_config
#    5220       )
#
# /usr/local/lib/python3.12/dist-packages/google/genai/models.py in _generate_content(self, model, contents, config)
#    3998     request_dict = _common.encode_unserializable_types(request_dict)
#    3999
# -> 4000     response = self._api_client.request(
#    4001         'post', path, request_dict, http_options
#    4002     )
#
# /usr/local/lib/python3.12/dist-packages/google/genai/_api_client.py in request(self, http_method, path, request_dict, http_options)
#    1328         http_method, path, request_dict, http_options
#    1329     )
# -> 1330     response = self._request(http_request, http_options, stream=False)
#    1331     response_body = (
#    1332         response.response_stream[0] if response.response_stream else ''
#
# /usr/local/lib/python3.12/dist-packages/google/genai/_api_client.py in _request(self, http_request, http_options, stream)
#    1164         return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
#    1165
# -> 1166     return self._retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
#    1167
#    1168   async def _async_request_once(
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in __call__(self, fn, *args, **kwargs)
#     475         retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     476         while True:
# --> 477             do = self.iter(retry_state=retry_state)
#     478             if isinstance(do, DoAttempt):
#     479                 try:
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in iter(self, retry_state)
#     376         result = None
#     377         for action in self.iter_state.actions:
# --> 378             result = action(retry_state)
#     379         return result
#     380
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in <lambda>(rs)
#     398     def _post_retry_check_actions(self, retry_state: "RetryCallState") -> None:
#     399         if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 400             self._add_action_func(lambda rs: rs.outcome.result())
#     401             return
#     402
#
# /usr/lib/python3.12/concurrent/futures/_base.py in result(self, timeout)
#     447                     raise CancelledError()
#     448                 elif self._state == FINISHED:
# --> 449                     return self.__get_result()
#     450
#     451                 self._condition.wait(timeout)
#
# /usr/lib/python3.12/concurrent/futures/_base.py in __get_result(self)
#     399         if self._exception:
#     400             try:
# --> 401                 raise self._exception
#     402             finally:
#     403                 # Break a reference cycle with the exception in self._exception
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in __call__(self, fn, *args, **kwargs)
#     478             if isinstance(do, DoAttempt):
#     479                 try:
# --> 480                     result = fn(*args, **kwargs)
#     481                 except BaseException:  # noqa: B902
#     482                     retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# /usr/local/lib/python3.12/dist-packages/google/genai/_api_client.py in _request_once(self, http_request, stream)
#    1134       )
#    1135     else:
# -> 1136       response = self._httpx_client.request(
#    1137           method=http_request.method,
#    1138           url=http_request.url,
#
# /usr/local/lib/python3.12/dist-packages/httpx/_client.py in request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     823             extensions=extensions,
#     824         )
# --> 825         return self.send(request, auth=auth, follow_redirects=follow_redirects)
#     826
#     827     @contextmanager
#
# /usr/local/lib/python3.12/dist-packages/httpx/_client.py in send(self, request, stream, auth, follow_redirects)
#     912         auth = self._build_request_auth(request, auth)
#     913
# --> 914         response = self._send_handling_auth(
#     915             request,
#     916             auth=auth,
#
# /usr/local/lib/python3.12/dist-packages/httpx/_client.py in _send_handling_auth(self, request, auth, follow_redirects, history)
#     940
#     941             while True:
# --> 942                 response = self._send_handling_redirects(
#     943                     request,
#     944                     follow_redirects=follow_redirects,
#
# /usr/local/lib/python3.12/dist-packages/httpx/_client.py in _send_handling_redirects(self, request, follow_redirects, history)
#     977                 hook(request)
#     978
# --> 979             response = self._send_single_request(request)
#     980             try:
#     981                 for hook in self._event_hooks["response"]:
#
# /usr/local/lib/python3.12/dist-packages/httpx/_client.py in _send_single_request(self, request)
#    1012
#    1013         with request_context(request=request):
# -> 1014             response = transport.handle_request(request)
#    1015
#    1016         assert isinstance(response.stream, SyncByteStream)
#
# /usr/local/lib/python3.12/dist-packages/httpx/_transports/default.py in handle_request(self, request)
#     248         )
#     249         with map_httpcore_exceptions():
# --> 250             resp = self._pool.handle_request(req)
#     251
#     252         assert isinstance(resp.stream, typing.Iterable)
#
# /usr/local/lib/python3.12/dist-packages/httpcore/_sync/connection_pool.py in handle_request(self, request)
#     254
#     255             self._close_connections(closing)
# --> 256             raise exc from None
#     257
#     258         # Return the response. Note that in this case we still have to manage
#
# /usr/local/lib/python3.12/dist-packages/httpcore/_sync/connection_pool.py in handle_request(self, request)
#     234                 try:
#     235                     # Send the request on the assigned connection.
# --> 236                     response = connection.handle_request(
#     237                         pool_request.request
#     238                     )
#
# /usr/local/lib/python3.12/dist-packages/httpcore/_sync/connection.py in handle_request(self, request)
#     101             raise exc
#     102
# --> 103         return self._connection.handle_request(request)
#     104
#     105     def _connect(self, request: Request) -> NetworkStream:
#
# /usr/local/lib/python3.12/dist-packages/httpcore/_sync/http11.py in handle_request(self, request)
#     134                 with Trace("response_closed", logger, request) as trace:
#     135                     self._response_closed()
# --> 136             raise exc
#     137
#     138     # Sending the request...
#
# /usr/local/lib/python3.12/dist-packages/httpcore/_sync/http11.py in handle_request(self, request)
#     104                     headers,
#     105                     trailing_data,
# --> 106                 ) = self._receive_response_headers(**kwargs)
#     107                 trace.return_value = (
#     108                     http_version,
#
# /usr/local/lib/python3.12/dist-packages/httpcore/_sync/http11.py in _receive_response_headers(self, request)
#     175
#     176         while True:
# --> 177             event = self._receive_event(timeout=timeout)
#     178             if isinstance(event, h11.Response):
#     179                 break
#
# /usr/local/lib/python3.12/dist-packages/httpcore/_sync/http11.py in _receive_event(self, timeout)
#     215
#     216             if event is h11.NEED_DATA:
# --> 217                 data = self._network_stream.read(
#     218                     self.READ_NUM_BYTES, timeout=timeout
#     219                 )
#
# /usr/local/lib/python3.12/dist-packages/httpcore/_backends/sync.py in read(self, max_bytes, timeout)
#     126         with map_exceptions(exc_map):
#     127             self._sock.settimeout(timeout)
# --> 128             return self._sock.recv(max_bytes)
#     129
#     130     def write(self, buffer: bytes, timeout: float | None = None) -> None:
#
# /usr/lib/python3.12/ssl.py in recv(self, buflen, flags)
#    1230                     "non-zero flags not allowed in calls to recv() on %s" %
#    1231                     self.__class__)
# -> 1232             return self.read(buflen)
#    1233         else:
#    1234             return super().recv(buflen, flags)
#
# /usr/lib/python3.12/ssl.py in read(self, len, buffer)
#    1103                 return self._sslobj.read(len, buffer)
#    1104             else:
# -> 1105                 return self._sslobj.read(len)
#    1106         except SSLError as x:
#    1107             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %%
from google.colab import drive, userdata
import os
import re
import time
from google import genai

# === Mount Google Drive and API ===
drive.mount('/content/drive')
os.environ["GOOGLE_API_KEY"] = userdata.get('GOOGLE_API_KEY')
client = genai.Client(api_key=os.environ["GOOGLE_API_KEY"])

# === Paths ===
base_dir = "/content/drive/My Drive/Test_quality/gemini25pro/"
asr_dir = os.path.join(base_dir, "Asr_eng")  # input SRTs
mt_dir = os.path.join(base_dir, "mt", "Tel")  # translated output
os.makedirs(mt_dir, exist_ok=True)

target_language = "Telugu"
print("🟢 Ready — Processing all .srt files...")

# === SRT parsing pattern ===
pattern = r"(\d+)\s+([\d:,]+ --> [\d:,]+)\s+(.+?)(?=\n\d+\n|$)"

def translate_segment(segment_text):
    """Translate a single subtitle segment at a time with Gemini."""
    prompt = f"""
You are a professional subtitle translator for Indic languages.

Translate the following subtitle dialogue into {target_language}.
Preserve meaning. Keep subtitles short and natural.
Do NOT translate numbers or timestamps.
Return one line per subtitle, in order.

Text:
{segment_text}
"""
    for _ in range(3):  # retry logic
        try:
            response = client.models.generate_content(
                model="gemini-2.5-pro",  # or gemini-2.0-pro if you have access
                contents=prompt
            )
            # Gemini's response object
            result_text = response.text.strip()
            return result_text
        except Exception as e:
            print("Retrying due to error:", e)
            time.sleep(3)
    return ""  # return empty if all retries fail

# === Loop over all SRT files ===
for f_name in os.listdir(asr_dir):
    if not f_name.lower().endswith(".srt"):
        continue

    input_file = os.path.join(asr_dir, f_name)
    print(f"\n🎬 Processing: {f_name}")

    with open(input_file, 'r', encoding='utf-8') as f:
        content = f.read()

    entries = re.findall(pattern, content, flags=re.DOTALL)
    print(f"   → {len(entries)} subtitles detected")

    translated_entries = []
    translated_text_only = []

    # Process each segment one by one
    for i, (num, ts, original_text) in enumerate(entries):
        print(f"   → Translating segment {i+1}: {original_text[:50]}...")  # Preview of text

        translated_text = translate_segment(original_text.strip())

        translated_entries.append(f"{num}\n{ts}\n{translated_text}\n")
        translated_text_only.append(translated_text)

        print(f"   ✅ Translated segment {i+1}")

    # Save outputs
    base = os.path.splitext(f_name)[0]
    srt_out = os.path.join(mt_dir, f"{base}_{target_language}.srt")
    txt_out = os.path.join(mt_dir, f"{base}_{target_language}.txt")

    with open(srt_out, "w", encoding='utf-8') as f:
        f.write("\n".join(translated_entries))

    with open(txt_out, "w", encoding='utf-8') as f:
        f.write("\n".join(translated_text_only))

    print(f"   📁 Saved → {srt_out}")
    print(f"   📄 Saved → {txt_out}")

print("\n✅ All files translated successfully!")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 🟢 Ready — Processing all .srt files...
#
# 🎬 Processing: Chapter 5A - Use of Growing and Rooting Media in Floriculture_gemini_25_pro_eng_eng.srt
#    → 66 subtitles detected
#    → Translating segment 1: Now, let us talk about the use of uh routing media...
#    ✅ Translated segment 1
#    → Translating segment 2: It helps in a water retention and drainage due to ...
#    ✅ Translated segment 2
#    → Translating segment 3: And uh it is it is also beneficial for the um uh m...
#    ✅ Translated segment 3
#    → Translating segment 4: Now, there are different types of growing media, i...
#    ✅ Translated segment 4
#    → Translating segment 5: This which are enriched with organic matter. These...
#    ✅ Translated segment 5
#    → Translating segment 6: This mixtures um it includes uh peat moss, uh coco...
#    ✅ Translated segment 6
#    → Translating segment 7: And we have another type that is organic media. Or...
#    ✅ Translated segment 7
#    → Translating segment 8: It uh improves the soil structure, it helps in the...
#    ✅ Translated segment 8
#    → Translating segment 9: Uh the other type is the inorganic media which mea...
#    ✅ Translated segment 9
#    → Translating segment 10: But the only drawback for this inorganic media is ...
#    ✅ Translated segment 10
#    → Translating segment 11: the the media should have an appropriate uh porosi...
#    ✅ Translated segment 11
#    → Translating segment 12: And uh the rooting and growing media should be suc...
#    ✅ Translated segment 12
#    → Translating segment 13: Uh now coming to the types of rooting media, there...
#    ✅ Translated segment 13
#    → Translating segment 14: It uh it's a natural fiber that is uh made from th...
#    ✅ Translated segment 14
#    → Translating segment 15: This uh rooting, this rooting media, these are hig...
#    ✅ Translated segment 15
#    → Translating segment 16: Perlite is a naturally um this occurring silicon r...
#    ✅ Translated segment 16
#    → Translating segment 17: which is uh mined and then it is processed into uh...
#    ✅ Translated segment 17
#    → Translating segment 18: Another type of rooting media is peat moss. Peat m...
#    ✅ Translated segment 18
#    → Translating segment 19: And uh though that uh peat moss also helps in reta...
#    ✅ Translated segment 19
#    → Translating segment 20: The last one is sand. Um it improves uh drainage a...
#    ✅ Translated segment 20
#    → Translating segment 21: Now, there are different applications for uh using...
#    ✅ Translated segment 21
#    → Translating segment 22: And I have this sand with me. So when we use cutti...
#    ✅ Translated segment 22
#    → Translating segment 23: Then when we uh grow them in the sand, after the r...
#    ✅ Translated segment 23
#    → Translating segment 24: And uh for and this mixture of coco peat, uh this ...
#    ✅ Translated segment 24
#    → Translating segment 25: So when we uh uh the common soil mixture, the root...
#    ✅ Translated segment 25
#    → Translating segment 26: So we will use them for um seedlings and cuttings....
#    ✅ Translated segment 26
#    → Translating segment 27: But the advantage of using this pro tray over a po...
#    ✅ Translated segment 27
#    → Translating segment 28: And it might damage all the plant, the seedling an...
#    ✅ Translated segment 28
#    → Translating segment 29: And while we see that one plant is already been in...
#    ✅ Translated segment 29
#    → Translating segment 30: These are only sand that I will use for cutting. S...
#    ✅ Translated segment 30
#    → Translating segment 31: So, and so on, we will keep filling the whole tray...
#    ✅ Translated segment 31
#    → Translating segment 32: And uh before grow uh planting the cuttings, we ne...
#    ✅ Translated segment 32
#    → Translating segment 33: There are different types of rooting hormone. uh l...
#    ✅ Translated segment 33
#    → Translating segment 34: This rooton hormone one is for uh soft um uh soft ...
#    ✅ Translated segment 34
#    → Translating segment 35: You can directly pour over it also. For cuttings, ...
#    ✅ Translated segment 35
#    → Translating segment 36: So, why we pour this um water before planting is b...
#    ✅ Translated segment 36
#    → Translating segment 37: That's why when we're going to use uh put the cutt...
#    ✅ Translated segment 37
#    → Translating segment 38: Okay, so we're mostly done watering it. First let ...
#    ✅ Translated segment 38
#    → Translating segment 39: I'll put them in a slanting position. And then I w...
#    ✅ Translated segment 39
#    → Translating segment 40: And you can directly plant it a little bit in a sl...
#    ✅ Translated segment 40
#    → Translating segment 41: till it dries off. So sand is something where the ...
#    ✅ Translated segment 41
#    → Translating segment 42: for the this new cuttings. This is a marigold seed...
#    ✅ Translated segment 42
#    → Translating segment 43: When you cut them, you use this secateur which is ...
#    ✅ Translated segment 43
#    → Translating segment 44: I have some hardwood cuttings also. This is Jatrop...
#    ✅ Translated segment 44
#    → Translating segment 45: The same manner, you're going to cut it. Remove so...
#    ✅ Translated segment 45
#    → Translating segment 46: Sorry. And you can use either uh rooton number two...
#    ✅ Translated segment 46
#    → Translating segment 47: Since this is not very hard, I'll use number two. ...
#    ✅ Translated segment 47
#    → Translating segment 48: While we cut the cuttings, it should always be sla...
#    ✅ Translated segment 48
#    → Translating segment 49: This is Bougainvillea. This is hardwood cutting, s...
#    ✅ Translated segment 49
#    → Translating segment 50: I cut the other parts so that those parts will tak...
#    ✅ Translated segment 50
#    → Translating segment 51: This is number three.
# ...
#    ✅ Translated segment 51
#    → Translating segment 52: Okay, so now I think we are clear that for cutting...
#    ✅ Translated segment 52
#    → Translating segment 53: Just a minute. And this is neem cake. I'll not use...
#    ✅ Translated segment 53
#    → Translating segment 54: If you don't want to use, you can avoid using it i...
#    ✅ Translated segment 54
#    → Translating segment 55: But if for transportation, you can use more of uh ...
#    ✅ Translated segment 55
#    → Translating segment 56: You can give it a good mix. And your one of your p...
#    ✅ Translated segment 56
#    → Translating segment 57: It is already mixed thoroughly. Now you can uh use...
#    ✅ Translated segment 57
#    → Translating segment 58: We have uh put the cuttings in the sand and then a...
#    ✅ Translated segment 58
#    → Translating segment 59: If you feel that the the poly bags are too big for...
#    ✅ Translated segment 59
#    → Translating segment 60: you put your seedlings and then you plant them nic...
#    ✅ Translated segment 60
#    → Translating segment 61: This is a cotton plant. This is also already roote...
#    ✅ Translated segment 61
#    → Translating segment 62: I'm going to throw this.
# ...
#    ✅ Translated segment 62
#    → Translating segment 63: It's half filled. Now, cover them. So, here are so...
#    ✅ Translated segment 63
#    → Translating segment 64: These are some of the cuttings I have shown uh alo...
#    ✅ Translated segment 64
#    → Translating segment 65: Uh the choice of growing and rooting media, it pla...
#    ✅ Translated segment 65
#    → Translating segment 66: So, by understanding the properties and functions ...
#    ✅ Translated segment 66
#    📁 Saved → /content/drive/My Drive/Test_quality/gemini25pro/mt/Tel/Chapter 5A - Use of Growing and Rooting Media in Floriculture_gemini_25_pro_eng_eng_Telugu.srt
#    📄 Saved → /content/drive/My Drive/Test_quality/gemini25pro/mt/Tel/Chapter 5A - Use of Growing and Rooting Media in Floriculture_gemini_25_pro_eng_eng_Telugu.txt
#
# 🎬 Processing: Chapter 1A - Concept of Basic Electricity Voltage, Currents, Resistance, Impedance & Power Factor.srt
#    → 129 subtitles detected
#    → Translating segment 1: Good morning to one and all present here. So this ...
#    ✅ Translated segment 1
#    → Translating segment 2: So I am working as a senior project officer in Cen...
#    ✅ Translated segment 2
#    → Translating segment 3: And regarding my educational qualification, I have...
#    ✅ Translated segment 3
#    → Translating segment 4: And I've completed my master's degree in engineeri...
#    ✅ Translated segment 4
#    → Translating segment 5: My total teaching experience, both teaching traini...
#    ✅ Translated segment 5
#    → Translating segment 6: so I'll be teaching this course electric motor rew...
#    ✅ Translated segment 6
#    → Translating segment 7: So here, we'll be dealing with starting from the c...
#    ✅ Translated segment 7
#    → Translating segment 8: So all the insights of the all the insights and th...
#    ✅ Translated segment 8
#    → Translating segment 9: So this will give you a person even without a degr...
#    ✅ Translated segment 9
#    → Translating segment 10: So now we are going to see the basic concepts of e...
#    ✅ Translated segment 10
#    → Translating segment 11: So current it is the rate of flow of electrons or ...
#    ✅ Translated segment 11
#    → Translating segment 12: So it is measured in amps, the unit is amps. So ne...
#    ✅ Translated segment 12
#    → Translating segment 13: Voltage is a electric potential difference between...
#    ✅ Translated segment 13
#    → Translating segment 14: And next is a resistance. Resistance is nothing bu...
#    ✅ Translated segment 14
#    → Translating segment 15: It is measured in ohms. Now we'll see what is Ohm'...
#    ✅ Translated segment 15
#    → Translating segment 16: At constant temperature, the voltage developed acr...
#    ✅ Translated segment 16
#    → Translating segment 17: So here we can see where we can apply Ohm's law.
# ...
#    ✅ Translated segment 17
#    → Translating segment 18: So Ohm's law, what is the mathematical way of repr...
#    ✅ Translated segment 18
#    → Translating segment 19: The Ohm's law can be applied only to the linear de...
#    ✅ Translated segment 19
#    → Translating segment 20: That is the electrical components where the curren...
#    ✅ Translated segment 20
#    → Translating segment 21: So Ohm's law cannot be applied to non-metallic con...
#    ✅ Translated segment 21
#    → Translating segment 22: So why do we actually use Ohm's law and what is th...
#    ✅ Translated segment 22
#    → Translating segment 23: So in order to find a specific resistance for a sp...
#    ✅ Translated segment 23
#    → Translating segment 24: So now we'll see what is meant by power factor.
# ...
#    ✅ Translated segment 24
#    → Translating segment 25: So power factor is nothing but a angular differenc...
#    ✅ Translated segment 25
#    → Translating segment 26: So power factor in terms of DC circuits, it can be...
#    ✅ Translated segment 26
#    → Translating segment 27: In case of AC circuits, the same power factor can ...
#    ✅ Translated segment 27
#    → Translating segment 28: So what is meant by this active power?
# ...
#    ✅ Translated segment 28
#    → Translating segment 29: For example, it can be this active power or the ap...
#    ✅ Translated segment 29
#    → Translating segment 30: So this foam which is not useful, so that we call ...
#    ✅ Translated segment 30
#    → Translating segment 31: The the juice that is actual quantity what you are...
#    ✅ Translated segment 31
#    → Translating segment 32: So this real power plus this reactive power, we ca...
#    ✅ Translated segment 32
#    → Translating segment 33: So here when the power factor is equal to one, so ...
#    ✅ Translated segment 33
#    → Translating segment 34: So there are two types of power factor, one is the...
#    ✅ Translated segment 34
#    → Translating segment 35: So when when the power factor will be leading or w...
#    ✅ Translated segment 35
#    → Translating segment 36: If you take in case of a resistive load, so any ty...
#    ✅ Translated segment 36
#    → Translating segment 37: So in that case, your power factor is equal to one...
#    ✅ Translated segment 37
#    → Translating segment 38: So when you take in case of any inductive load, so...
#    ✅ Translated segment 38
#    → Translating segment 39: So here that we call it as a lagging power factor....
#    ✅ Translated segment 39
#    → Translating segment 40: So next is a when you take a capacitive load, so y...
#    ✅ Translated segment 40
#    → Translating segment 41: So how do you say it is a leading power factor? Cu...
#    ✅ Translated segment 41
#    → Translating segment 42: So you call it as a leading power factor.
# ...
#    ✅ Translated segment 42
#    → Translating segment 43: So there are various methods to improve this power...
#    ✅ Translated segment 43
#    → Translating segment 44: So we always we have to maintain that power factor...
#    ✅ Translated segment 44
#    → Translating segment 45: So that we optimally use the electrical in we opti...
#    ✅ Translated segment 45
#    → Translating segment 46: Fire prevention in electrical system.
# ...
#    ✅ Translated segment 46
#    → Translating segment 47: Electrical fire possess a significant threat to sa...
#    ✅ Translated segment 47
#    → Translating segment 48: This incident often occur due to malfunction in el...
#    ✅ Translated segment 48
#    → Translating segment 49: Such sparks and overheating can ignite nearby mate...
#    ✅ Translated segment 49
#    → Translating segment 50: creating a serious risk to both individuals and pr...
#    ✅ Translated segment 50
#    → Translating segment 51: To help to prevent the potential fires, it is esse...
#    ✅ Translated segment 51
#    → Translating segment 52: Additionally, ensuring that electrical work is per...
#    ✅ Translated segment 52
#    → Translating segment 53: So here some common causes of fire in electrical s...
#    ✅ Translated segment 53
#    → Translating segment 54: Overload circuits, electrical equipment failure, s...
#    ✅ Translated segment 54
#    → Translating segment 55: Improper use of electrical devices, lack of mainte...
#    ✅ Translated segment 55
#    → Translating segment 56: Let us take a closer look at each of these causes....
#    ✅ Translated segment 56
#    → Translating segment 57: One of the most common causes of electrical fires ...
#    ✅ Translated segment 57
#    → Translating segment 58: Older buildings or facilities with aging electrica...
#    ✅ Translated segment 58
#    → Translating segment 59: Overloading wires. Older electrical system may not...
#    ✅ Translated segment 59
#    → Translating segment 60: loose or poorly connected wires can cause electric...
#    ✅ Translated segment 60
#    → Translating segment 61: And overloading them by plugging into too many hig...
#    ✅ Translated segment 61
#    → Translating segment 62: causing the wires to overheat and potential ignite...
#    ✅ Translated segment 62
#    → Translating segment 63: Another causes electrical equipment failure. Elect...
#    ✅ Translated segment 63
#    → Translating segment 64: The motors that are not properly maintained or tha...
#    ✅ Translated segment 64
#    → Translating segment 65: aging equipment. Equipment that has been in operat...
#    ✅ Translated segment 65
#    → Translating segment 66: Short circuits occur when electrical current bypas...
#    ✅ Translated segment 66
#    → Translating segment 67: Next one is damaged insulation. If the insulation ...
#    ✅ Translated segment 67
#    → Translating segment 68: Improper or unsafe use of electrical devices is a ...
#    ✅ Translated segment 68
#    → Translating segment 69: plugging devices into outlets that cannot handle t...
#    ✅ Translated segment 69
#    → Translating segment 70: The neglected maintenance, the failing to perform ...
#    ✅ Translated segment 70
#    → Translating segment 71: Without regular inspections, electrical faults lik...
#    ✅ Translated segment 71
#    → Translating segment 72: Here are precaution for electrical system to preve...
#    ✅ Translated segment 72
#    → Translating segment 73: Replace outdated wiring and electrical systems. In...
#    ✅ Translated segment 73
#    → Translating segment 74: Use proper electrical devices and cords. Protect e...
#    ✅ Translated segment 74
#    → Translating segment 75: Let us take a closer look at each of these precaut...
#    ✅ Translated segment 75
#    → Translating segment 76: To prevent electrical fire caused by overloaded ci...
#    ✅ Translated segment 76
#    → Translating segment 77: Use deducted circuits for high power devices like ...
#    ✅ Translated segment 77
#    → Translating segment 78: Upgrade the circuit breakers. Install suitable cir...
#    ✅ Translated segment 78
#    → Translating segment 79: Regular maintenance and inspection of electrical s...
#    ✅ Translated segment 79
#    → Translating segment 80: Schedule inspection, first one is. Implement a rou...
#    ✅ Translated segment 80
#    → Translating segment 81: Next check one, check for overheating. During insp...
#    ✅ Translated segment 81
#    → Translating segment 82: Clean electrical panels and units. Dust and debris...
#    ✅ Translated segment 82
#    → Translating segment 83: Next precaution is replace outdated wiring and ele...
#    ✅ Translated segment 83
#    → Translating segment 84: To protect electrical system, to upgrade to modern...
#    ✅ Translated segment 84
#    → Translating segment 85: Some older buildings may have aluminium wiring whi...
#    ✅ Translated segment 85
#    → Translating segment 86: Next precaution is install the fire detection and ...
#    ✅ Translated segment 86
#    → Translating segment 87: Install smoke detectors are near electrical units,...
#    ✅ Translated segment 87
#    → Translating segment 88: Use heat sensor in area with high electrical loads...
#    ✅ Translated segment 88
#    → Translating segment 89: This system can extinguish the fire without damagi...
#    ✅ Translated segment 89
#    → Translating segment 90: Use extension card safely. Avoid using extension c...
#    ✅ Translated segment 90
#    → Translating segment 91: Choose properly rated equipment. Ensure that elect...
#    ✅ Translated segment 91
#    → Translating segment 92: Next, label circuit breakers. Clearly label circui...
#    ✅ Translated segment 92
#    → Translating segment 93: Water, dust and other environmental factors can le...
#    ✅ Translated segment 93
#    → Translating segment 94: particularly in area prone to leak or exposure to ...
#    ✅ Translated segment 94
#    → Translating segment 95: Use such protection device to guard against voltag...
#    ✅ Translated segment 95
#    → Translating segment 96: Knowing how to respond effectively can prevent the...
#    ✅ Translated segment 96
#    → Translating segment 97: First one is cut off the power source. If it is sa...
#    ✅ Translated segment 97
#    → Translating segment 98: This type of extinguisher is specifically designed...
#    ✅ Translated segment 98
#    → Translating segment 99: Never use water. Water conduct the electricity and...
#    ✅ Translated segment 99
#    → Translating segment 100: Alert others in the vicinity. Inform coworkers to ...
#    ✅ Translated segment 100
#    → Translating segment 101: Shut down electrical operation if possible. If it ...
#    ✅ Translated segment 101
#    → Translating segment 102: The fire extinguisher are essential safety device ...
#    ✅ Translated segment 102
#    → Translating segment 103: Oxygen displacement. The CO2 gas is heavier than o...
#    ✅ Translated segment 103
#    → Translating segment 104: Next the CO2 gas also very cold as it is come out ...
#    ✅ Translated segment 104
#    → Translating segment 105: The CO2 extinguisher are safe to use on electrical...
#    ✅ Translated segment 105
#    → Translating segment 106: The a dry chemical powder extinguisher works by in...
#    ✅ Translated segment 106
#    → Translating segment 107: When the dry chemical powder is expred from the ex...
#    ✅ Translated segment 107
#    → Translating segment 108: The powder create a barrier between the fuel and t...
#    ✅ Translated segment 108
#    → Translating segment 109: First one is pull. The pull the pin to break the t...
#    ✅ Translated segment 109
#    → Translating segment 110: Next one is aim. Aim low pointing the nozzle or ho...
#    ✅ Translated segment 110
#    → Translating segment 111: Next one is squeeze the handle to release the exti...
#    ✅ Translated segment 111
#    → Translating segment 112: The fuel source until the fire is extinguished. Le...
#    ✅ Translated segment 112
#    → Translating segment 113: As discussed earlier, in the before slide, uh, her...
#    ✅ Translated segment 113
#    → Translating segment 114: Next one is discharge hose. So, this will be very ...
#    ✅ Translated segment 114
#    → Translating segment 115: fire extinguisher having safety pin, throttle wall...
#    ✅ Translated segment 115
#    → Translating segment 116: So now, we are going to use the ABC type fire exti...
#    ✅ Translated segment 116
#    → Translating segment 117: Now we remove pin. Aim the base of the fire.
# ...
#    ✅ Translated segment 117
#    → Translating segment 118: And squeeze the gently the lever, discharge lever....
#    ✅ Translated segment 118
#    → Translating segment 119: Uh, next, next was going to be see the another fir...
#    ✅ Translated segment 119
#    → Translating segment 120: So, what is the method of using through pass metho...
#    ✅ Translated segment 120
#    → Translating segment 121: Aim the bottom of the fire. Next, open the throttl...
#    ✅ Translated segment 121
#    → Translating segment 122: CO2 gas was applied on the fire. So, now oxygen wa...
#    ✅ Translated segment 122
#    → Translating segment 123: In the demonstration, we saw the both the extingui...
#    ✅ Translated segment 123
#    → Translating segment 124: And another one is CO2 extinguisher. This extingui...
#    ✅ Translated segment 124
#    → Translating segment 125: So at the end of the section, as we warp our elect...
#    ✅ Translated segment 125
#    → Translating segment 126: recognize the common causes of electrical fire suc...
#    ✅ Translated segment 126
#    → Translating segment 127: Regularly inspect and maintain the electrical syst...
#    ✅ Translated segment 127
#    → Translating segment 128: Know the different type of fire extinguisher and t...
#    ✅ Translated segment 128
#    → Translating segment 129: By adhering to these guidelines, we can significan...
#    ✅ Translated segment 129
#    📁 Saved → /content/drive/My Drive/Test_quality/gemini25pro/mt/Tel/Chapter 1A - Concept of Basic Electricity Voltage, Currents, Resistance, Impedance & Power Factor_Telugu.srt
#    📄 Saved → /content/drive/My Drive/Test_quality/gemini25pro/mt/Tel/Chapter 1A - Concept of Basic Electricity Voltage, Currents, Resistance, Impedance & Power Factor_Telugu.txt
#
# ✅ All files translated successfully!

# %%
from google.colab import drive, userdata
import os
import re
import time
from google import genai

# === Mount Google Drive and API ===
drive.mount('/content/drive')
os.environ["GOOGLE_API_KEY"] = userdata.get('GOOGLE_API_KEY')
client = genai.Client(api_key=os.environ["GOOGLE_API_KEY"])

# === Paths ===
base_dir = "/content/drive/My Drive/Test_quality/gemini25pro/"
asr_dir = os.path.join(base_dir, "Asr_eng")  # input SRTs
mt_dir = os.path.join(base_dir, "mt", "Mal")  # translated output
os.makedirs(mt_dir, exist_ok=True)

target_language = "Malayalam"
print("🟢 Ready — Processing all .srt files...")

# === SRT parsing pattern ===
pattern = r"(\d+)\s+([\d:,]+ --> [\d:,]+)\s+(.+?)(?=\n\d+\n|$)"

def translate_batch(lines):
    """Translate list of subtitle text chunks at once with Gemini."""
    joined_text = "\n".join(lines)
    prompt = f"""
You are a professional subtitle translator for Indic languages.

Translate the following subtitle dialogue into {target_language}.
Preserve meaning. Keep subtitles short and natural.
Do NOT translate numbers or timestamps.
Return one line per subtitle, in order.

Text:
{joined_text}
"""
    for _ in range(3):  # retry logic
        try:
            response = client.models.generate_content(
                model="gemini-2.5-pro",  # or gemini-2.0-pro if you have access
                contents=prompt
            )
            # Gemini's response object
            result_text = response.text.strip()
            return result_text.split("\n")
        except Exception as e:
            print("Retrying batch due to error:", e)
            time.sleep(3)
    return [""] * len(lines)

# === Loop over all SRT files ===
for f_name in os.listdir(asr_dir):
    if not f_name.lower().endswith(".srt"):
        continue

    input_file = os.path.join(asr_dir, f_name)
    print(f"\n🎬 Processing: {f_name}")

    with open(input_file, 'r', encoding='utf-8') as f:
        content = f.read()

    entries = re.findall(pattern, content, flags=re.DOTALL)
    print(f"   → {len(entries)} subtitles detected")

    translated_entries = []
    translated_text_only = []

    batch_size = 15
    for i in range(0, len(entries), batch_size):
        batch = entries[i:i+batch_size]
        orig_texts = [t[2].strip() for t in batch]

        translated_batch = translate_batch(orig_texts)

        for (num, ts, _), trans in zip(batch, translated_batch):
            translated_entries.append(f"{num}\n{ts}\n{trans}\n")
            translated_text_only.append(trans)

        print(f"   ✅ Translated segments {i+1}–{min(i+batch_size,len(entries))}")

    # Save outputs
    base = os.path.splitext(f_name)[0]
    srt_out = os.path.join(mt_dir, f"{base}_{target_language}.srt")
    txt_out = os.path.join(mt_dir, f"{base}_{target_language}.txt")

    with open(srt_out, "w", encoding='utf-8') as f:
        f.write("\n".join(translated_entries))

    with open(txt_out, "w", encoding='utf-8') as f:
        f.write("\n".join(translated_text_only))

    print(f"   📁 Saved → {srt_out}")
    print(f"   📄 Saved → {txt_out}")

print("\n✅ All files translated successfully!")
# Out:
# Mounted at /content/drive
# 🟢 Ready — Processing all .srt files...
#
# 🎬 Processing: Chapter 1A - Concept of Basic Electricity Voltage, Currents, Resistance, Impedance & Power Factor.srt
#    → 129 subtitles detected
#    ✅ Translated segments 1–15
#    ✅ Translated segments 16–30
#    ✅ Translated segments 31–45
#    ✅ Translated segments 46–60
#    ✅ Translated segments 61–75
#    ✅ Translated segments 76–90
#    ✅ Translated segments 91–105
#    ✅ Translated segments 106–120
# Retrying batch due to error: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}
#    ✅ Translated segments 121–129
#    📁 Saved → /content/drive/My Drive/Test_quality/gemini25pro/mt/Mal/Chapter 1A - Concept of Basic Electricity Voltage, Currents, Resistance, Impedance & Power Factor_Malayalam.srt
#    📄 Saved → /content/drive/My Drive/Test_quality/gemini25pro/mt/Mal/Chapter 1A - Concept of Basic Electricity Voltage, Currents, Resistance, Impedance & Power Factor_Malayalam.txt
#
# 🎬 Processing: Chapter 5A - Use of Growing and Rooting Media in Floriculture_gemini_25_pro_eng_eng.srt
#    → 66 subtitles detected
#    ✅ Translated segments 1–15
#    ✅ Translated segments 16–30
#    ✅ Translated segments 31–45
#    ✅ Translated segments 46–60
#    ✅ Translated segments 61–66
#    📁 Saved → /content/drive/My Drive/Test_quality/gemini25pro/mt/Mal/Chapter 5A - Use of Growing and Rooting Media in Floriculture_gemini_25_pro_eng_eng_Malayalam.srt
#    📄 Saved → /content/drive/My Drive/Test_quality/gemini25pro/mt/Mal/Chapter 5A - Use of Growing and Rooting Media in Floriculture_gemini_25_pro_eng_eng_Malayalam.txt
#
# ✅ All files translated successfully!
